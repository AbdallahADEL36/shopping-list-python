# %%
a=[]

# %%
a.append("iphone")
a.append("samsung")
a.append("infinix")

# %%
a.append("redmi")

# %%
a[0]
# Out:
# 'iphone'

# %%
a
# Out:
# ['iphone', 'samsung', 'infinix', 'redmi']

# %%
a[-1]
# Out:
# 'redmi'

# %%
a
# Out:
# ['iphone', 'samsung', 'infinix', 'redmi']

# %%
del(a[1])

# %%
a
# Out:
# ['iphone', 'infinix', 'redmi']
